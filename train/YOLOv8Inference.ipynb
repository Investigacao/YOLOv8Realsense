# %%
from ultralytics import YOLO
model = YOLO('./runs/segment/arvore/weights/best.pt')
model.predict(source="./datasets/treeDataset/test/images/IMG_20230515_110505_2_jpg.rf.3ed88a390de5777d8011da13d39705c3.jpg", show=True)
# Out:
# image 1/1 /home/pedrobolsa/Documents/Escola/Investigacao/YoloV8/train/datasets/treeDataset/test/images/IMG_20230515_110505_2_jpg.rf.3ed88a390de5777d8011da13d39705c3.jpg: 640x640 5 Oranges, 1 TreeTop, 1 Trunk, 8.6ms
# Speed: 3.0ms preprocess, 8.6ms inference, 9.7ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes', 'masks']
#  masks: ultralytics.yolo.engine.results.Masks object
#  names: {0: 'Orange', 1: 'TreeTop', 2: 'Trunk'}
#  orig_img: array([[[228, 226, 225],
#          [232, 230, 229],
#          [228, 226, 225],
#          ...,
#          [ 85, 128, 145],
#          [ 85, 128, 145],
#          [ 84, 127, 144]],
#
#         [[203, 201, 200],
#          [209, 207, 206],
#          [210, 208, 207],
#          ...,
#          [ 86, 129, 146],
#          [ 86, 129, 146],
#          [ 85, 128, 145]],
#
# ...

# %%
from ultralytics import YOLO
model = YOLO('./runs/segment/tomate/weights/best.pt')
results = model.predict(source="./output.mp4", show=True)
# for i, result in enumerate(esults):
#     boxes = result.boxes
#     for box in boxes:
#         xyxy = box.xyxy[0]
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from ultralytics import YOLO
#       2 model = YOLO('./runs/segment/tomate/weights/best.pt')
# ----> 3 results = model.predict(source="./output.mp4", show=True)
#       4 # for i, result in enumerate(results):
#       5 #     boxes = result.boxes
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics.yolo.engine.model import YOLO


model = YOLO('./runs/segment/tomate/weights/best.pt')
model.to('cuda')

# force to run on CPU by using device flag
results = model.predict(source="./output.mp4", stream=True, show=True)
for i, result in enumerate(results):
    boxes = result.boxes
    # masks = result.masks
    print(f"result: {result}")
    for box in boxes:
        xyxy = box.xyxy[0] 
        print("xyxy: ", xyxy)
    # for mask in masks:
    #     print("mask: ", mask)
# Out:
# video 1/1 (1/5942) /home/pedrobolsa/Documents/Escola/Investigacao/YoloV8/train/output.mp4: 384x640 29 Green-Tomatos, 71.1ms
# video 1/1 (2/5942) /home/pedrobolsa/Documents/Escola/Investigacao/YoloV8/train/output.mp4: 384x640 31 Green-Tomatos, 12.0ms
# video 1/1 (3/5942) /home/pedrobolsa/Documents/Escola/Investigacao/YoloV8/train/output.mp4: 384x640 30 Green-Tomatos, 11.9ms
# video 1/1 (4/5942) /home/pedrobolsa/Documents/Escola/Investigacao/YoloV8/train/output.mp4: 384x640 27 Green-Tomatos, 11.1ms
# video 1/1 (5/5942) /home/pedrobolsa/Documents/Escola/Investigacao/YoloV8/train/output.mp4: 384x640 28 Green-Tomatos, 11.2ms
# video 1/1 (6/5942) /home/pedrobolsa/Documents/Escola/Investigacao/YoloV8/train/output.mp4: 384x640 31 Green-Tomatos, 11.1ms
# video 1/1 (7/5942) /home/pedrobolsa/Documents/Escola/Investigacao/YoloV8/train/output.mp4: 384x640 28 Green-Tomatos, 11.4ms
# result: ultralytics.yolo.engine.results.Results object with attributes:
#
# ...
